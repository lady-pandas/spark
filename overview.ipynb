# %%
cluster_info_cols = [
    'spark.databricks.clusterUsageTags.clusterNodeType', 
    'spark.databricks.clusterUsageTags.clusterMaxWorkers', 
    'spark.databricks.clusterUsageTags.clusterMinWorkers'
]
cluster_config = {el[0].replace('spark.databricks.clusterUsageTags.', ''): el[1] for el in spark.sparkContext.getConf().getAll() if el[0] in cluster_info_cols}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
if cluster_config['clusterNodeType']=='Standard_DS5_v2':
    cluster_config['GB'] = 56
    cluster_config['core'] = 16
elif cluster_config['clusterNodeType']=='Standard_DS3_v2':
    cluster_config['GB'] = 14
    cluster_config['core'] = 4
elif cluster_config['clusterNodeType']=="dev-tier-node":
    cluster_config['GB'] = 15.3
    cluster_config['core'] = 2
    
del cluster_config['clusterNodeType']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Boston data

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_boston
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
boston = load_boston()

boston_pd = pd.DataFrame(
    data= np.c_[boston['data'], boston['target']],
    columns= np.append(boston['feature_names'], 'target')
)
boston_pd.head(5), boston_pd.shape[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: (      CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
#  0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
#  1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
#  2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
#  3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
#  4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
#
#  [5 rows x 14 columns],
#  506)</div>

# %% [markdown]
# # RF - sklearn

# %%
from sklearn.ensemble import RandomForestRegressor
from scipy.stats.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train, test = train_test_split(boston_pd, test_size=0.2, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Sztuczne powiększenie danych - tylko dla celów testowych

# %%
n = train.shape[0] * 1 #1000
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train = train.sample(n, replace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
y_train = train['target']
X_train = train.drop(['target'], axis=1)

y_test = test['target']
X_test = test.drop(['target'], axis=1)

# rf = RandomForestRegressor()
# model = rf.fit(X_train, y_train)

# y_pred = model.predict(X_test)

# mae = mean_absolute_error(y_test, y_pred)
# print("MAE: " + str(mae))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #RF with tracking

# %%
seed = 42  # for repeatability purposes
default_params = {'n_estimators': 200, 'max_depth': 10}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import time
import mlflow
import mlflow.sklearn
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mlflow.start_run(run_name="sklearn")

rf = RandomForestRegressor(n_estimators=default_params['n_estimators'], max_depth=default_params['max_depth'], random_state=seed)

start = time.time()
model = rf.fit(X_train, y_train)
end = time.time()

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)

mlflow.log_metrics({
    "time": end-start,
    "mae": mae,
})
mlflow.log_params(cluster_config)
mlflow.log_param("n", X_train.shape[0])
mlflow.sklearn.log_model(model, "model")

mlflow.end_run()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# features importances
pd.DataFrame({'var': X_train.columns, 'imp': model.feature_importances_}).sort_values('imp', ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>var</th>
#       <th>imp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12</th>
#       <td>LSTAT</td>
#       <td>0.511157</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>RM</td>
#       <td>0.316889</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>DIS</td>
#       <td>0.068010</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>CRIM</td>
#       <td>0.035081</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NOX</td>
#       <td>0.024399</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>TAX</td>
#       <td>0.010394</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>AGE</td>
#       <td>0.009572</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>B</td>
#       <td>0.009096</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>PTRATIO</td>
#       <td>0.006358</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>INDUS</td>
#       <td>0.005410</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>RAD</td>
#       <td>0.002382</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ZN</td>
#       <td>0.000848</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CHAS</td>
#       <td>0.000404</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
def save_model(save, run_name, cluster_config, time, mae, n, cv, parallelism, model, lib):
    if save:
        mlflow.start_run(run_name=run_name)

        mlflow.log_metrics({
            "time": time,
            "mae": mae,
        })
        mlflow.log_params(cluster_config)
        mlflow.log_params({"n": n, 'cv': cv, 'parallelism': parallelism})
        lib.log_model(model, "model")

        mlflow.end_run()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
save = True
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #MLlib
#
# https://spark.apache.org/docs/latest/ml-classification-regression.html

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.ml.regression import RandomForestRegressor as RandomForestRegressorSpark
from pyspark.ml.evaluation import RegressionEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import mlflow.spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_spark = spark.createDataFrame(train).withColumnRenamed('target', 'label')
test_spark = spark.createDataFrame(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assembler = VectorAssembler(inputCols= list(X_train.columns), outputCol="features")
# https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.ml.regression.RandomForestRegressor.html#pyspark.ml.regression.RandomForestRegressor
rf = RandomForestRegressorSpark(numTrees=default_params['n_estimators'], maxDepth=default_params['max_depth'], seed=seed)


pipeline = Pipeline(stages = [assembler, rf])

start = time.time()
model = pipeline.fit(train_spark)
end = time.time()

test_pred_spark = model.transform(test_spark)

evaluator = RegressionEvaluator(labelCol='target', predictionCol="prediction", metricName="mae")
mae = evaluator.evaluate(test_pred_spark)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
save_model(save, "mllib", cluster_config, end-start, mae, train_spark.count(), None, None, model, mlflow.spark)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Grid search

# %%
cv = 10
parameters = {'n_estimators': [10, 100, 200], 'max_depth': [5, 10, 15], 'random_state':[42]}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Grid search with cross validation - sklearn

# %%
from sklearn.model_selection import GridSearchCV
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf = RandomForestRegressor()
gs = GridSearchCV(rf, parameters, cv=cv, scoring='neg_mean_absolute_error')
start = time.time()
gs.fit(X_train, y_train)
end = time.time()
end - start

save_model(save, "sklearn-grid", cluster_config, end-start, abs(gs.best_score_), X_train.shape[0], cv, None, gs.best_estimator_, mlflow.sklearn)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#pd.DataFrame(gs.cv_results_)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Grid search with parallelism

# %%
parallelism = 4
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.utils import parallel_backend
# !pip install joblibspark
from joblibspark import register_spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: joblibspark in /databricks/conda/envs/databricks-ml/lib/python3.8/site-packages (0.3.0)
# Requirement already satisfied: joblib&gt;=0.14 in /databricks/conda/envs/databricks-ml/lib/python3.8/site-packages (from joblibspark) (0.17.0)
# </div>

# %%
register_spark() # register spark backend

start = time.time()
with parallel_backend("spark", n_jobs=parallelism):
    gs.fit(X_train, y_train)
end = time.time()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gs.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: {&#39;max_depth&#39;: 15, &#39;n_estimators&#39;: 200, &#39;random_state&#39;: 42}</div>

# %%
save_model(save, "sklearn-grid-parallel", cluster_config, end-start, abs(gs.best_score_), X_train.shape[0], cv, parallelism, gs.best_estimator_, mlflow.sklearn)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Grid search with cross validation - MLlib

# %%
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf = RandomForestRegressorSpark()
pipeline = Pipeline(stages = [assembler, rf])
evaluator = RegressionEvaluator(labelCol='label', predictionCol="prediction", metricName="mae")

paramGrid = ParamGridBuilder()\
    .addGrid(rf.maxDepth, parameters['max_depth'])\
    .addGrid(rf.numTrees, parameters['n_estimators'])\
    .addGrid(rf.seed, parameters['random_state'])\
    .build()

cvSpark = CrossValidator(
    estimator=pipeline, 
    evaluator=evaluator,
    estimatorParamMaps=paramGrid,
    numFolds=cv,
    parallelism=parallelism,
    seed=seed
)

#pipeline = Pipeline(stages = [assembler, rf, cvSpark])

start = time.time()
cvModel = cvSpark.fit(train_spark)
end = time.time()

# %%
cvModel.getEstimatorParamMaps()[ np.argmin(cvModel.avgMetrics) ].values()

# %%
save_model(save, "mllib-grid-parallel", cluster_config, end-start, min(cvModel.avgMetrics), train_spark.count(), cv, parallelism, cvModel.bestModel, mlflow.spark)

# %% [markdown]
# # H20
#
# https://pypi.org/project/h2o-pysparkling-3.1/
#
# http://docs.h2o.ai/sparkling-water/3.1/latest-stable/doc/pysparkling.html
#
# https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/drf.html

# %%
from pysparkling import *
import h2o
from h2o.estimators.random_forest import H2ORandomForestEstimator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import mlflow.h2o  # https://www.mlflow.org/docs/latest/python_api/mlflow.h2o.html
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hc = H2OContext.getOrCreate();
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Connecting to H2O server at http://10.172.255.94:54323 ... successful.
# --------------------------  -------------------------------------------------------------------------------------------------------
# H2O_cluster_uptime:         21 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.1.2
# H2O_cluster_version_age:    22 days
# H2O_cluster_name:           sparkling-water-root_local-1621666039048
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    6.896 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://10.172.255.94:54323
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         XGBoost, Algos, Amazon S3, Sparkling Water REST API Extensions, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  -------------------------------------------------------------------------------------------------------
#
# Sparkling Water Context:
#  * Sparkling Water Version: 3.32.1.2-1-3.1
#  * H2O name: sparkling-water-root_local-1621666039048
#  * cluster size: 1
#  * list of used nodes:
#   (executorId, host, port)
#   ------------------------
#   (0,10.172.255.94,54321)
#   ------------------------
#
#   Open H2O Flow in browser: http://10.172.255.94:54323 (CMD + click in Mac OSX)
#
#
# </div>

# %%
train_h2o = h2o.H2OFrame(train)
test_h2o = h2o.H2OFrame(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# </div>

# %%
rf_h2o = H2ORandomForestEstimator(
    ntrees=default_params['n_estimators'],
    max_depth=default_params['max_depth'],
    seed=seed
)

start = time.time()
rf_h2o.train(list(X_train.columns), 'target', training_frame=train_h2o, validation_frame=test_h2o)
end = time.time()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1532616151016582&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> rf_h2o = H2ORandomForestEstimator(
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg">     </span>ntrees<span class="ansi-blue-fg">=</span>default_params<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;n_estimators&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>     max_depth<span class="ansi-blue-fg">=</span>default_params<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;max_depth&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>     seed<span class="ansi-blue-fg">=</span>seed
# <span class="ansi-green-intense-fg ansi-bold">      5</span> )
#
# <span class="ansi-red-fg">NameError</span>: name &#39;default_params&#39; is not defined</div>

# %%
#rf_h2o.varimp()

# %%
save_model(save, "h2o", cluster_config, end-start, rf_h2o.mae(valid=True), train_h2o.nrow, None, None, rf_h2o, spark.h2o)

# %% [markdown]
# # Grid search with H2O

# %%
from h2o.grid.grid_search import H2OGridSearch
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
parameters_h2o = parameters.copy()
parameters_h2o['ntrees'] = parameters_h2o['n_estimators']
parameters_h2o['seed'] = parameters_h2o['random_state']
del parameters_h2o['n_estimators']
del parameters_h2o['random_state']

parameters_h2o, parameters
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: ({&#39;max_depth&#39;: [5, 10, 15], &#39;ntrees&#39;: [10, 100, 200], &#39;seed&#39;: [42]},
#  {&#39;n_estimators&#39;: [10, 100, 200],
#   &#39;max_depth&#39;: [5, 10, 15],
#   &#39;random_state&#39;: [42]})</div>

# %%
gs_h2o = H2OGridSearch(
    model=H2ORandomForestEstimator,
    hyper_params=parameters_h2o,
    parallelism=parallelism,
   # search_criteria={'strategy': 'Cartesian', 'stopping_metric': 'mae'}
)

start = time.time()
gs_h2o.train(list(X_train.columns), 'target', training_frame=train_h2o, seed=seed)
end = time.time()

best_gs_h2o = gs_h2o.get_grid(sort_by='mae', decreasing=False).models[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">drf Grid Build progress: |████████████████████████████████████████████████| 100%
# </div>

# %%
best_gs_h2o.params['ntrees']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: {&#39;default&#39;: 50, &#39;actual&#39;: 200, &#39;input&#39;: 200}</div>

# %%
save_model(save, "h2o-grid", cluster_config, end-start, best_gs_h2o.mae(test_h2o), train_h2o.nrow, cv, parallelism, best_gs_h2o , mlflow.h2o)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Koalas vs Pandas
#
# https://koalas.readthedocs.io/en/latest/

# %%
import databricks.koalas as ks
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_cat = train.copy()
train_cat['AGE_CAT'] = pd.cut(train_cat['AGE'], bins=3, labels=['one', 'two', 'three']).astype(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_ks = ks.from_pandas(train_cat)
test_ks = ks.from_pandas(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_ks.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CRIM</th>
#       <th>ZN</th>
#       <th>INDUS</th>
#       <th>CHAS</th>
#       <th>NOX</th>
#       <th>RM</th>
#       <th>AGE</th>
#       <th>DIS</th>
#       <th>RAD</th>
#       <th>TAX</th>
#       <th>PTRATIO</th>
#       <th>B</th>
#       <th>LSTAT</th>
#       <th>target</th>
#       <th>AGE_CAT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>477</th>
#       <td>15.02340</td>
#       <td>0.0</td>
#       <td>18.10</td>
#       <td>0.0</td>
#       <td>0.6140</td>
#       <td>5.304</td>
#       <td>97.3</td>
#       <td>2.1007</td>
#       <td>24.0</td>
#       <td>666.0</td>
#       <td>20.2</td>
#       <td>349.48</td>
#       <td>24.91</td>
#       <td>12.0</td>
#       <td>three</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.62739</td>
#       <td>0.0</td>
#       <td>8.14</td>
#       <td>0.0</td>
#       <td>0.5380</td>
#       <td>5.834</td>
#       <td>56.5</td>
#       <td>4.4986</td>
#       <td>4.0</td>
#       <td>307.0</td>
#       <td>21.0</td>
#       <td>395.62</td>
#       <td>8.47</td>
#       <td>19.9</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>0.03466</td>
#       <td>35.0</td>
#       <td>6.06</td>
#       <td>0.0</td>
#       <td>0.4379</td>
#       <td>6.031</td>
#       <td>23.3</td>
#       <td>6.6407</td>
#       <td>1.0</td>
#       <td>304.0</td>
#       <td>16.9</td>
#       <td>362.25</td>
#       <td>7.83</td>
#       <td>19.4</td>
#       <td>one</td>
#     </tr>
#     <tr>
#       <th>423</th>
#       <td>7.05042</td>
#       <td>0.0</td>
#       <td>18.10</td>
#       <td>0.0</td>
#       <td>0.6140</td>
#       <td>6.103</td>
#       <td>85.1</td>
#       <td>2.0218</td>
#       <td>24.0</td>
#       <td>666.0</td>
#       <td>20.2</td>
#       <td>2.52</td>
#       <td>23.29</td>
#       <td>13.4</td>
#       <td>three</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.72580</td>
#       <td>0.0</td>
#       <td>8.14</td>
#       <td>0.0</td>
#       <td>0.5380</td>
#       <td>5.727</td>
#       <td>69.5</td>
#       <td>3.7965</td>
#       <td>4.0</td>
#       <td>307.0</td>
#       <td>21.0</td>
#       <td>390.95</td>
#       <td>11.28</td>
#       <td>18.2</td>
#       <td>three</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ks.sql("SELECT * FROM {train_ks} WHERE AGE > 80").shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: (191, 15)</div>

# %%
train_ks.groupby(['AGE_CAT']).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CRIM</th>
#       <th>ZN</th>
#       <th>INDUS</th>
#       <th>CHAS</th>
#       <th>NOX</th>
#       <th>RM</th>
#       <th>AGE</th>
#       <th>DIS</th>
#       <th>RAD</th>
#       <th>TAX</th>
#       <th>PTRATIO</th>
#       <th>B</th>
#       <th>LSTAT</th>
#       <th>target</th>
#     </tr>
#     <tr>
#       <th>AGE_CAT</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>two</th>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>one</th>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_cat.groupby(['AGE_CAT']).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CRIM</th>
#       <th>ZN</th>
#       <th>INDUS</th>
#       <th>CHAS</th>
#       <th>NOX</th>
#       <th>RM</th>
#       <th>AGE</th>
#       <th>DIS</th>
#       <th>RAD</th>
#       <th>TAX</th>
#       <th>PTRATIO</th>
#       <th>B</th>
#       <th>LSTAT</th>
#       <th>target</th>
#     </tr>
#     <tr>
#       <th>AGE_CAT</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>one</th>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#       <td>237</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#       <td>95</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Użyteczne transformacje

# %%
train_cat_spark = spark.createDataFrame(train_cat)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Window

# %%
from pyspark.sql.window import Window
from pyspark.sql import functions as f
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
window = Window.partitionBy('AGE_CAT')

train_cat_spark\
    .withColumn('avg_age', f.rank().over(window.orderBy(f.asc('AGE'))))\
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRIM</th><th>ZN</th><th>INDUS</th><th>CHAS</th><th>NOX</th><th>RM</th><th>AGE</th><th>DIS</th><th>RAD</th><th>TAX</th><th>PTRATIO</th><th>B</th><th>LSTAT</th><th>target</th><th>AGE_CAT</th><th>avg_age</th></tr></thead><tbody><tr><td>0.12744</td><td>0.0</td><td>6.91</td><td>0.0</td><td>0.448</td><td>6.77</td><td>2.9</td><td>5.7209</td><td>3.0</td><td>233.0</td><td>17.9</td><td>385.41</td><td>4.84</td><td>26.6</td><td>one</td><td>1</td></tr><tr><td>0.07896</td><td>0.0</td><td>12.83</td><td>0.0</td><td>0.437</td><td>6.273</td><td>6.0</td><td>4.2515</td><td>5.0</td><td>398.0</td><td>18.7</td><td>394.92</td><td>6.78</td><td>24.1</td><td>one</td><td>2</td></tr><tr><td>0.15936</td><td>0.0</td><td>6.91</td><td>0.0</td><td>0.448</td><td>6.211</td><td>6.5</td><td>5.7209</td><td>3.0</td><td>233.0</td><td>17.9</td><td>394.46</td><td>7.44</td><td>24.7</td><td>one</td><td>3</td></tr><tr><td>
3</td><td>7.6534</td><td>3.0</td><td>402.0</td><td>17.0</td><td>396.9</td><td>4.56</td><td>34.9</td><td>one</td><td>15</td></tr><tr><td>0.02177</td><td>82.5</td><td>2.03</td><td>0.0</td><td>0.415</td><td>7.61</td><td>15.7</td><td>6.27</td><td>2.0</td><td>348.0</td><td>14.7</td><td>395.38</td><td>3.11</td><td>42.3</td><td>one</td><td>16</td></tr><tr><td>0.03359</td><td>75.0</td><td>2.95</td><td>0.0</td><td>0.428</td><td>7.024</td><td>15.8</td><td>5.4011</td><td>3.0</td><td>252.0</td>< ...

# %% [markdown]
# ## ApplyInPandas

# %%
from sklearn.model_selection import cross_val_score
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def train_rf(data):
    rf = RandomForestRegressor()
    
    y_train = data['target']
    X_train = data.drop(['target', 'AGE_CAT'], axis=1)
    
    mae = cross_val_score(rf, X_train, y_train, cv=cv, scoring='neg_mean_absolute_error')
    print(mae)
    return pd.DataFrame({'fold': range(cv), 'mae': mae, 'age': data['AGE_CAT'].max()})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_rf(train_cat)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[-1.91334146 -2.45597561 -1.97746341 -2.93387805 -3.32985    -2.072425
#  -2.9879     -2.037375   -1.728975   -2.578025  ]
# Out[60]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fold</th>
#       <th>mae</th>
#       <th>age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>-1.913341</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>-2.455976</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>-1.977463</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>-2.933878</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>-3.329850</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>-2.072425</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>-2.987900</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>-2.037375</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>-1.728975</td>
#       <td>two</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>-2.578025</td>
#       <td>two</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# https://spark.apache.org/docs/3.1.1/api/python/reference/api/pyspark.sql.types.StructField.html
schema = StructType([
    StructField('fold', IntegerType(), True),
    StructField('mae', DoubleType(), True),
    StructField('age', StringType(), True),
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
res = train_cat_spark\
    .groupBy('AGE_CAT')\
    .applyInPandas(train_rf, schema)

res.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fold</th><th>mae</th><th>age</th></tr></thead><tbody><tr><td>0</td><td>-1.5386249999999992</td><td>one</td></tr><tr><td>1</td><td>-1.377750000000002</td><td>one</td></tr><tr><td>2</td><td>-0.9377142857142812</td><td>one</td></tr><tr><td>3</td><td>-2.7218571428571416</td><td>one</td></tr><tr><td>4</td><td>-2.5819999999999985</td><td>one</td></tr><tr><td>5</td><td>-3.3784285714285622</td><td>one</td></tr><tr><td>6</td><td>-1.6040000000000039</td><td>one</td></tr><tr><td>7</td><td>-1.8562857142857168</td><td>one</td></tr><tr><td>8</td><td>-1.0334285714285711</td><td>one</td></tr><tr><td>9</td><td>-1.7900000000000031</td><td>one</td></tr><tr><td>0</td><td>-2.3608749999999987</td><td>three</td></tr><tr><td>1</td><td>-3.2322499999999987</td><td>three</td></tr><tr><td>2</td><td>-2.6520000000000006</td><td>three</td></tr><tr><td>3</td><td>-3.1854583333333335</td><td>three</td></tr><tr><td>4</td><td>-3.3627916666666664</td><td>three</td></tr><tr><td>5</td><td>-2.0391666666666706</td><td>three</td></tr><tr><td>6</td><td>-3.0089583333333345</td><td>three</td></tr><tr><td>
td>-1.6260000000000059</td><td>one</td></tr><tr><td>8</td><td>-1.0804285714285666</td><td>one</td></tr><tr><td>9</td><td>-1.9154285714285701</td><td>one</td></tr><tr><td>0</td><td>-2.334500000000001</td><td>three</td></tr><tr><td>1</td><td>-3.242791666666669</td><td>three</td></tr><tr><td>2</td><td>-2.641666666666667</td><td>three</td></tr><tr><td>3</td><td>-3.227416666666669</td><td>three</td></tr><tr><td>4</td><td>-3.3081250000000004</td><td>three</td></tr><tr><td>5</td><td>-2.1706666666666723</td><td>three</td></tr><tr><td>6</td><td>-3.0510000000000006</td><td>three</td></tr><tr><td>7</td><td>-2.0947391304347867</td><td>three</td></tr><tr><td>8</td><td>-2.0118260869565225</td><td>three</td></tr><tr><td>9</td><td>-3.9565652173913026</td><td>three</td></tr></tbody></table></div>

# %%
res\
    .groupBy('age')\
    .pivot('fold')\
    .agg(f.avg('mae').alias('mae'))\
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>0</th><th>1</th><th>2</th><th>3</th><th>4</th><th>5</th><th>6</th><th>7</th><th>8</th><th>9</th></tr></thead><tbody><tr><td>two</td><td>-3.0482000000000005</td><td>-1.2151999999999998</td><td>-1.8446999999999965</td><td>-1.558000000000003</td><td>-2.8642000000000007</td><td>-3.792333333333332</td><td>-3.6705555555555573</td><td>-1.595888888888892</td><td>-2.259</td><td>-1.886444444444441</td></tr><tr><td>one</td><td>-1.5140000000000007</td><td>-1.445250000000009</td><td>-1.0128571428571402</td><td>-2.5741428571428533</td><td>-2.873428571428573</td><td>-3.3518571428571318</td><td>-1.9650000000000034</td><td>-1.6260000000000059</td><td>-1.0804285714285666</td><td>-1.9154285714285701</td></tr><tr><td>three</td><td>-2.334500000000001</td><td>-3.242791666666669</td><td>-2.641666666666667</td><td>-3.227416666666669</td><td>-3.3081250000000004</td><td>-2.1706666666666723</td><td>-3.0510000000000006</td><td>-2.0947391304347867</td><td>-2.0118260869565225</td><td>-3.9565652173913026</td></tr></tbody></table></div>

# %% [markdown]
# ## Reduce

# %%
from pyspark.sql import DataFrame # https://spark.apache.org/docs/3.1.1/api/python/reference/api/pyspark.sql.DataFrame.html?highlight=datafram
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from functools import reduce
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train, test = train_test_split(boston_pd, test_size=0.2, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_spark = spark.createDataFrame(train)
test_spark = spark.createDataFrame(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_array = [train_spark, test_spark]
all_data = reduce(DataFrame.unionAll, train_array)
all_data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[71]: 506</div>

# %%
all_data.toPandas().head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CRIM</th>
#       <th>ZN</th>
#       <th>INDUS</th>
#       <th>CHAS</th>
#       <th>NOX</th>
#       <th>RM</th>
#       <th>AGE</th>
#       <th>DIS</th>
#       <th>RAD</th>
#       <th>TAX</th>
#       <th>PTRATIO</th>
#       <th>B</th>
#       <th>LSTAT</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15.02340</td>
#       <td>0.0</td>
#       <td>18.10</td>
#       <td>0.0</td>
#       <td>0.6140</td>
#       <td>5.304</td>
#       <td>97.3</td>
#       <td>2.1007</td>
#       <td>24.0</td>
#       <td>666.0</td>
#       <td>20.2</td>
#       <td>349.48</td>
#       <td>24.91</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.62739</td>
#       <td>0.0</td>
#       <td>8.14</td>
#       <td>0.0</td>
#       <td>0.5380</td>
#       <td>5.834</td>
#       <td>56.5</td>
#       <td>4.4986</td>
#       <td>4.0</td>
#       <td>307.0</td>
#       <td>21.0</td>
#       <td>395.62</td>
#       <td>8.47</td>
#       <td>19.9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.03466</td>
#       <td>35.0</td>
#       <td>6.06</td>
#       <td>0.0</td>
#       <td>0.4379</td>
#       <td>6.031</td>
#       <td>23.3</td>
#       <td>6.6407</td>
#       <td>1.0</td>
#       <td>304.0</td>
#       <td>16.9</td>
#       <td>362.25</td>
#       <td>7.83</td>
#       <td>19.4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.05042</td>
#       <td>0.0</td>
#       <td>18.10</td>
#       <td>0.0</td>
#       <td>0.6140</td>
#       <td>6.103</td>
#       <td>85.1</td>
#       <td>2.0218</td>
#       <td>24.0</td>
#       <td>666.0</td>
#       <td>20.2</td>
#       <td>2.52</td>
#       <td>23.29</td>
#       <td>13.4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.72580</td>
#       <td>0.0</td>
#       <td>8.14</td>
#       <td>0.0</td>
#       <td>0.5380</td>
#       <td>5.727</td>
#       <td>69.5</td>
#       <td>3.7965</td>
#       <td>4.0</td>
#       <td>307.0</td>
#       <td>21.0</td>
#       <td>390.95</td>
#       <td>11.28</td>
#       <td>18.2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## UDF

# %%
import math
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@udf(returnType=DoubleType()) 
def udf_sqrt(x):
    return math.sqrt(x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
all_data.withColumn('x2', udf_sqrt('TAX')).limit(2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRIM</th><th>ZN</th><th>INDUS</th><th>CHAS</th><th>NOX</th><th>RM</th><th>AGE</th><th>DIS</th><th>RAD</th><th>TAX</th><th>PTRATIO</th><th>B</th><th>LSTAT</th><th>target</th><th>x2</th></tr></thead><tbody><tr><td>15.0234</td><td>0.0</td><td>18.1</td><td>0.0</td><td>0.614</td><td>5.304</td><td>97.3</td><td>2.1007</td><td>24.0</td><td>666.0</td><td>20.2</td><td>349.48</td><td>24.91</td><td>12.0</td><td>25.80697580112788</td></tr><tr><td>0.62739</td><td>0.0</td><td>8.14</td><td>0.0</td><td>0.538</td><td>5.834</td><td>56.5</td><td>4.4986</td><td>4.0</td><td>307.0</td><td>21.0</td><td>395.62</td><td>8.47</td><td>19.9</td><td>17.52141546793523</td></tr></tbody></table></div>

# %%
all_data.withColumn('x2', f.sqrt('TAX')).limit(2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRIM</th><th>ZN</th><th>INDUS</th><th>CHAS</th><th>NOX</th><th>RM</th><th>AGE</th><th>DIS</th><th>RAD</th><th>TAX</th><th>PTRATIO</th><th>B</th><th>LSTAT</th><th>target</th><th>x2</th></tr></thead><tbody><tr><td>15.0234</td><td>0.0</td><td>18.1</td><td>0.0</td><td>0.614</td><td>5.304</td><td>97.3</td><td>2.1007</td><td>24.0</td><td>666.0</td><td>20.2</td><td>349.48</td><td>24.91</td><td>12.0</td><td>25.80697580112788</td></tr><tr><td>0.62739</td><td>0.0</td><td>8.14</td><td>0.0</td><td>0.538</td><td>5.834</td><td>56.5</td><td>4.4986</td><td>4.0</td><td>307.0</td><td>21.0</td><td>395.62</td><td>8.47</td><td>19.9</td><td>17.52141546793523</td></tr></tbody></table></div>

# %%
all_data.write.mode('overwrite').parquet('/FileStore/test.parquet')

# https://community.cloud.databricks.com/?o=2097898880805746#tables/new/dbfs
# https://mungingdata.com/apache-spark/partitionby/#:~:text=partitionBy()%20is%20a%20DataFrameWriter,important%20independent%20of%20disk%20partitioning.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Expanding

# %%
train_cat_spark\
    .withColumn('age_q', f.expr('percentile(AGE, array(0.0, 0.5, 1.0))').over(Window.partitionBy('AGE_CAT')))\
    .withColumn("q", f.array(f.lit(0), f.lit(0.5), f.lit(1.0)))\
    .withColumn("zipped", f.arrays_zip(*(["q"] + ['age_q'])))\
    .drop(*(["q"]))\
    .withColumn("zipped", f.explode("zipped"))\
    .select("AGE_CAT", "zipped.*").drop("zipped")\
    .dropDuplicates()\
    .orderBy('AGE_CAT', 'q')\
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AGE_CAT</th><th>q</th><th>age_q</th></tr></thead><tbody><tr><td>one</td><td>0.0</td><td>2.9</td></tr><tr><td>one</td><td>0.5</td><td>22.6</td></tr><tr><td>one</td><td>1.0</td><td>34.9</td></tr><tr><td>three</td><td>0.0</td><td>67.8</td></tr><tr><td>three</td><td>0.5</td><td>91.6</td></tr><tr><td>three</td><td>1.0</td><td>100.0</td></tr><tr><td>two</td><td>0.0</td><td>35.7</td></tr><tr><td>two</td><td>0.5</td><td>52.9</td></tr><tr><td>two</td><td>1.0</td><td>67.2</td></tr></tbody></table></div>

# %% [markdown]
# #Other languages

# %% [markdown]
# ## Scala

# %%
# %scala

var data_spark = spark.read.parquet("/FileStore/test.parquet")

display(data_spark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRIM</th><th>ZN</th><th>INDUS</th><th>CHAS</th><th>NOX</th><th>RM</th><th>AGE</th><th>DIS</th><th>RAD</th><th>TAX</th><th>PTRATIO</th><th>B</th><th>LSTAT</th><th>target</th></tr></thead><tbody><tr><td>0.33147</td><td>0.0</td><td>6.2</td><td>0.0</td><td>0.507</td><td>8.247</td><td>70.4</td><td>3.6519</td><td>8.0</td><td>307.0</td><td>17.4</td><td>378.95</td><td>3.95</td><td>48.3</td></tr><tr><td>0.3692</td><td>0.0</td><td>9.9</td><td>0.0</td><td>0.544</td><td>6.567</td><td>87.3</td><td>3.6023</td><td>4.0</td><td>304.0</td><td>18.4</td><td>395.69</td><td>9.28</td><td>23.8</td></tr><tr><td>2.24236</td><td>0.0</td><td>19.58</td><td>0.0</td><td>0.605</td><td>5.854</td><td>91.8</td><td>2.422</td><td>5.0</td><td>403.0</td><td>14.7</td><td>395.11</td><td>11.64</td><td>22.7</td></tr><tr><td>0.32264</td><td>0.0</td><td>21.89</td><td>0.0</td><td>0.624</td><td>5.942</td><td>93.5</td><td>1.9669</td><td>4.0</td><td>437.0</td><td>21.2</td><td>378.25</td><td>16.9</td><td>17.4</td></tr><tr><td>0.04666</td><td>80.0</td><td>1.52</td><td>0.0</td><td>0.404</td><td>7.107</td><td>36.6</td><td>7.309</td><td>2.0</td><td>329.0</td><td>12.6</td><td
td><td>0.0</td><td>18.1</td><td>0.0</td><td>0.713</td><td>6.417</td><td>98.3</td><td>2.185</td>< ...

# %% [markdown]
# ## R
#
# https://spark.apache.org/docs/latest/sparkr.html#:~:text=SparkR%20is%20an%20R%20package,dplyr)%20but%20on%20large%20datasets.

# %%
# %r
library(SparkR)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p">
# Attaching package: ‘SparkR’
#
# The following object is masked _by_ ‘.GlobalEnv’:
#
#     setLocalProperty
#
# The following objects are masked from ‘package:stats’:
#
#     cov, filter, lag, na.omit, predict, sd, var, window
#
# The following objects are masked from ‘package:base’:
#
#     as.data.frame, colnames, colnames&lt;-, drop, endsWith, intersect,
#     rank, rbind, sample, startsWith, subset, summary, transform, union
#
# </pre><pre style = 'font-size:10pt'></pre>

# %%
# %r
data_r <- read.parquet("/FileStore/test.parquet")
head(data_r)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'>     CRIM ZN INDUS CHAS   NOX    RM   AGE    DIS RAD TAX PTRATIO      B LSTAT
# 1 0.33147  0  6.20    0 0.507 8.247  70.4 3.6519   8 307    17.4 378.95  3.95
# 2 0.36920  0  9.90    0 0.544 6.567  87.3 3.6023   4 304    18.4 395.69  9.28
# 3 2.24236  0 19.58    0 0.605 5.854  91.8 2.4220   5 403    14.7 395.11 11.64
# 4 0.32264  0 21.89    0 0.624 5.942  93.5 1.9669   4 437    21.2 378.25 16.90
# 5 0.04666 80  1.52    0 0.404 7.107  36.6 7.3090   2 329    12.6 354.31  8.61
# 6 0.66351 20  3.97    0 0.647 7.333 100.0 1.8946   5 264    13.0 383.29  7.79
#   target
# 1   48.3
# 2   23.8
# 3   22.7
# 4   17.4
# 5   30.3
# 6   36.0</pre>

# %%
# %r
head(select(data_r, "CRIM"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'>     CRIM
# 1 0.33147
# 2 0.36920
# 3 2.24236
# 4 0.32264
# 5 0.04666
# 6 0.66351</pre>

# %% [markdown]
# ## SQL

# %%
# %sql
CREATE DATABASE test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
all_data.write.saveAsTable("test.boston")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sql('select * from test.boston').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CRIM</th><th>ZN</th><th>INDUS</th><th>CHAS</th><th>NOX</th><th>RM</th><th>AGE</th><th>DIS</th><th>RAD</th><th>TAX</th><th>PTRATIO</th><th>B</th><th>LSTAT</th><th>target</th></tr></thead><tbody><tr><td>0.33147</td><td>0.0</td><td>6.2</td><td>0.0</td><td>0.507</td><td>8.247</td><td>70.4</td><td>3.6519</td><td>8.0</td><td>307.0</td><td>17.4</td><td>378.95</td><td>3.95</td><td>48.3</td></tr><tr><td>0.3692</td><td>0.0</td><td>9.9</td><td>0.0</td><td>0.544</td><td>6.567</td><td>87.3</td><td>3.6023</td><td>4.0</td><td>304.0</td><td>18.4</td><td>395.69</td><td>9.28</td><td>23.8</td></tr><tr><td>2.24236</td><td>0.0</td><td>19.58</td><td>0.0</td><td>0.605</td><td>5.854</td><td>91.8</td><td>2.422</td><td>5.0</td><td>403.0</td><td>14.7</td><td>395.11</td><td>11.64</td><td>22.7</td></tr><tr><td>0.32264</td><td>0.0</td><td>21.89</td><td>0.0</td><td>0.624</td><td>5.942</td><td>93.5</td
td><td>0.0</td><td>18.1</td><td>0.0</td><td>0.668</td><td>4.138</td><td>100.0</td><td>1.137</td><td>24.0</td><td>666.0</td><td>20.2</td><td>396.9</td><td>37.97</td><td>13.8</td></tr><tr><td>7.52601</td><td>0.0</td><td>18.1</td><td>0.0</td><td>0.713</td><td>6.417</td><td>98.3</td><td>2.185</td>< ...

# %%
# %sql
# drop DATABASE asdf

# %% [markdown]
# # Joins
#
# ## Cross join

# %%
parameters = {'n_estimators': [10, 100, 200], 'max_depth': [5, 10, 15], 'random_state':[42]}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.types import FloatType
import pandas as pd

params_spark = spark.createDataFrame(pd.DataFrame({'n_estimators': [10, 100, 200]}))
params_spark.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>n_estimators</th></tr></thead><tbody><tr><td>10</td></tr><tr><td>100</td></tr><tr><td>200</td></tr></tbody></table></div>

# %%
sql('select * from test.boston').crossJoin(params_spark).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 1518</div>

# %% [markdown]
# ## Join

# %%
data = sql('select * from test.boston').withColumn('id', f.monotonically_increasing_id())

data.select('id', 'CRIM').join(data.select('id', 'PTRATIO').limit(2), on='id', how='left').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>CRIM</th><th>PTRATIO</th></tr></thead><tbody><tr><td>0</td><td>0.33147</td><td>17.4</td></tr><tr><td>1</td><td>0.3692</td><td>18.4</td></tr><tr><td>2</td><td>2.24236</td><td>null</td></tr><tr><td>3</td><td>0.32264</td><td>null</td></tr><tr><td>4</td><td>0.04666</td><td>null</td></tr><tr><td>5</td><td>0.66351</td><td>null</td></tr><tr><td>6</td><td>0.57529</td><td>null</td></tr><tr><td>7</td><td>0.17134</td><td>null</td></tr><tr><td>8</td><td>0.06899</td><td>null</td></tr><tr><td>9</td><td>0.07244</td><td>null</td></tr><tr><td>10</td><td>0.31533</td><td>null</td></tr><tr><td>11</td><td>20.7162</td><td>null</td></tr><tr><td>12</td><td>0.06151</td><td>null</td></tr><tr><td>13</td><td>0.25915</td><td>null</td></tr><tr><td>14</td><td>0.01096</td><td>null</td></tr><tr><td>15</td><td>18.0846</td><td>null</td></tr><tr><td>16</td><td>0.13117</td><td>null</td></tr><tr><td>17</td><td>18.4982</td><td>null</td></tr><tr><td>18</td><td>7.52601</td><td>null</td></tr><tr><td>19</td><td>0.32982</td><td>null</td></tr><tr><td>20</td><td>13.5222</td><td>null</td></tr><tr><td>21</td><td>0.12269</td><td>null</td></tr><tr><td>22</td><td>0.17899</td><td>null</td></tr><tr><td>23</td><td>0.03584</td><td>null</td></tr><tr><td>24</td><td>0.01501</td><td>null</td></tr><tr><td>25</td><td>0.05735</td><td>null</td></tr><tr><td>26</td><td>0.1029</td><td>null</td></tr><tr><td>27</td><td>0.05602</td><td>null</td></tr><tr><td>28</td><td>15.8603</td><td>null</td></tr><tr><td>29</td><td>1.42502</td><td>null</td></tr><tr><td>30</td><td>0.09378</td><td>null</td></tr><tr><td>31</td><td>0.06417</td><td>null</td></tr><tr><td>32</td><td>0.77299</td><td>null</td></tr><tr><td>33</td><td>1.20742</td><td>null</td></tr><tr><td>34</td><td>3.32105</td><td>null</td></tr><tr><td>35</td><td>9.59571</td><td>null</td></tr><tr><td>36</td><td>0.02899</td><td>null</td></tr><tr><td>37</td><td>0.40771</td><td>null</td></tr><tr><td>38</td><td>0.12204</td><td>null</td></tr><tr><td>39</td><td>0.04337</td><td>null</td></tr><tr><td>40</td><td>0.11329</td><td>null</td></tr><tr><td>41</td><td>15.288</td><td>null</td></tr><tr><td>42</td><td>9.18702</td><td>null</td></tr><tr><td>43</td><td>0.06642</td><td>null</td></tr><tr><td>44</td><td>0.12744</td><td>null</td></tr><tr><td>45</td><td>22.0511</td><td>null</td></tr><tr><td>46</td><td>5.29305</td><td>null</td></tr><tr><td>47</td><td>0.22969</td><td>null</td></tr><tr><td>48</td><td>0.06129</td><td>null</td></tr><tr><td>49</td><td>0.04819</td><td>null</td></tr><tr><td>50</td><td>6.39312</td><td>null</td></tr><tr><td>51</td><td>0.05561</td><td>null</td></tr><tr><td>52</td><td>0.05372</td><td>null</td></tr><tr><td>53</td><td>0.03768</td><td>null</td></tr><tr><td>54</td><td>9.82349</td><td>null</td></tr><tr><td>55</td><td>2.15505</td><td>null</td></tr><tr><td>56</td><td>5.87205</td><td>null</td></tr><tr><td>57</td><td>2.36862</td><td>null</td></tr><tr><td>58</td><td>7.36711</td><td>null</td></tr><tr><td>59</td><td>0.04297</td><td>null</td></tr><tr><td>60</td><td>0.15038</td><td>null</td></tr><tr><td>61</td><td>0.20746</td><td>null</td></tr><tr><td>62</td><td>0.11504</td><td>null</td></tr><tr><td>63</td><td>4.0974</td><td>null</td></tr><tr><td>64</td><td>0.09252</td><td>null</td></tr><tr><td>65</td><td>0.09604</td><td>null</td></tr><tr><td>66</td><td>0.12083</td><td>null</td></tr><tr><td>67</td><td>0.01709</td><td>null</td></tr><tr><td>68</td><td>0.09299</td><td>null</td></tr><tr><td>69</td><td>0.10008</td><td>null</td></tr><tr><td>70</td><td>0.02177</td><td>null</td></tr><tr><td>71</td><td>0.33983</td><td>null</td></tr><tr><td>72</td><td>2.37857</td><td>null</td></tr><tr><td>73</td><td>0.03537</td><td>null</td></tr><tr><td>74</td><td>0.04301</td><td>null</td></tr><tr><td>75</td><td>51.1358</td><td>null</td></tr><tr><td>76</td><td>9.91655</td><td>null</td></tr><tr><td>77</td><td>0.01965</td><td>null</td></tr><tr><td>78</td><t ...

# %%
# %scala
import org.apache.spark.sql.functions._ 

var data = sql("select * from test.boston").withColumn("id", monotonicallyIncreasingId)

var subset1 = data.select("id", "CRIM")
var subset2 = data.select("id", "PTRATIO").limit(2)

display(subset1.join(subset2, subset1("id") === subset2("id"), "inner"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>CRIM</th><th>id</th><th>PTRATIO</th></tr></thead><tbody><tr><td>0</td><td>0.33147</td><td>0</td><td>17.4</td></tr><tr><td>1</td><td>0.3692</td><td>1</td><td>18.4</td></tr></tbody></table></div>

# %% [markdown]
# #Hyperopt
#
# https://docs.databricks.com/_static/notebooks/hyperopt-spark-mlflow.html

# %%
from hyperopt import fmin, tpe, rand, hp, SparkTrials, Trials, STATUS_OK
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# function to minimize
def objective(C):
    rf = RandomForestRegressor(C)
    
    mae = cross_val_score(rf, X_train, y_train, cv=cv, scoring='neg_mean_absolute_error').mean()
    
    return {'loss': -mae, 'status': STATUS_OK}

# search space
values = [5, 10, 50, 100, 500]
search_space = hp.choice('C', values)
# rand
algo=rand.suggest
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# argmin = fmin(
#   fn=objective,
#   space=search_space,
#   algo=algo,
#   max_evals=3
# )
# values[argmin['C']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
#   0%|          | 0/3 [00:00&lt;?, ?trial/s, best loss=?]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
spark_trials = SparkTrials(parallelism=4)
 
with mlflow.start_run():
    argmin = fmin(
        fn=objective,
        space=search_space,
        algo=algo,
        max_evals=3,
        trials=spark_trials
    )
# Print the best value found for C
print("Best value found: ", values[argmin['C']])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hyperopt with SparkTrials will automatically track trials in MLflow. To view the MLflow experiment associated with the notebook, click the &#39;Runs&#39; icon in the notebook context bar on the upper right. There, you can view all runs.
# To view logs from trials, please check the Spark executor logs. To view executor logs, expand &#39;Spark Jobs&#39; above until you see the (i) icon next to the stage from the trial job. Click it and find the list of tasks. Click the &#39;stderr&#39; link for a task to view trial logs.
# 100%|██████████| 3/3 [00:09&lt;00:00,  3.14s/trial, best loss: 2.5306485148514852]
# Total Trials: 3: 3 succeeded, 0 failed, 0 cancelled.
# Best value found:  100
# </div>

# %%
help(SparkTrials)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on class SparkTrials in module hyperopt.spark:
#
# class SparkTrials(hyperopt.base.Trials)
#   SparkTrials(parallelism=None, timeout=None, loss_threshold=None, spark_session=None)
#
#   Implementation of hyperopt.Trials supporting
#   distributed execution using Apache Spark clusters.
#   This requires fmin to be run on a Spark cluster.
#
#   Plugging SparkTrials into hyperopt.fmin() allows hyperopt
#   to send model training and evaluation tasks to Spark workers,
#   parallelizing hyperparameter search.
#   Each trial (set of hyperparameter values) is handled within
#   a single Spark task; i.e., each model will be fit and evaluated
#   on a single worker machine.  Trials are run asynchronously.
#
#   See hyperopt.Trials docs for general information about Trials.
#
#   The fields we store in our trial docs match the base Trials class.  The fields include:
#    - &#39;tid&#39;: trial ID
#    - &#39;state&#39;: JOB_STATE_DONE, JOB_STATE_ERROR, etc.
#    - &#39;result&#39;: evaluation result for completed trial run
#    - &#39;refresh_time&#39;: timestamp for last status update
#    - &#39;misc&#39;: includes:
#       - &#39;error&#39;: (error type, error message)
#    - &#39;book_time&#39;: timestamp for trial run start
#
#   Method resolution order:
#       SparkTrials
#       hyperopt.base.Trials
#       builtins.object
#
#   Methods defined here:
#
#   __init__(self, parallelism=None, timeout=None, loss_threshold=None, spark_session=None)
#       :param parallelism: Maximum number of parallel trials to run,
#                           i.e., maximum number of concurrent Spark tasks.
#                           The actual parallelism is subject to available Spark task slots at
#                           runtime.
#                           If set to None (default) or a non-positive value, this will be set to
#                           Spark&#39;s default parallelism, or the current total of Spark task slots,
#                           or `1`, whichever is greater.
#                           We cap the value at `MAX_CONCURRENT_JOBS_ALLOWED=128`.
#       :param timeout: Maximum time (in seconds) which fmin is allowed to take.
#                       If this timeout is hit, then fmin will cancel running and proposed trials.
#                       It will retain all completed trial runs and return the best result found
#                       so far.
#       :param spark_session: A SparkSession object. If None is passed, SparkTrials will attempt
#                             to use an existing SparkSession or create a new one. SparkSession is
#                             the entry point for various facilities provided by Spark. For more
#                             information, visit the documentation for PySpark.
#
#   count_cancelled_trials(self)
#       Returns the current number of cancelled trial runs.
#       This covers trials which are cancelled from exceeding the timeout.
#
#   count_failed_trials(self)
#       Returns the current number of trial runs which failed
#
#   count_successful_trials(self)
#       Returns the current number of trials which ran successfully
#
#   count_total_trials(self)
#       Returns the current number of all successful, failed, and cancelled trial runs
#
#   delete_all(self)
#       Reset the Trials to init state
#
#   fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file=&#39;&#39;)
#       This should not be called directly but is called via :func:`hyperopt.fmin`
#       Refer to :func:`hyperopt.fmin` for docs on each argument
#
#   mlflow_log_best_loss(self, best_loss)
#
#   trial_attachments(self, trial)
#       Support syntax for load:  self.trial_attachments(doc)[name]
#       # -- does this work syntactically?
#       #    (In any event a 2-stage store will work)
#       Support syntax for store: self.trial_attachments(doc)[name] = value
#
#   ----------------------------------------------------------------------
#   Data and other attributes defined here:
#
#   MAX_CONCURRENT_JOBS_ALLOWED = 128
#
#   asynchronous = True
#
#   ----------------------------------------------------------------------
#   Methods inherited from hyperopt.base.Trials:
#
#   __getitem__(self, item)
#
#   __iter__(self)
#
#   __len__(self)
#
#   aname(self, trial, name)
#
#   assert_valid_trial(self, trial)
#
#   average_best_error(self, bandit=None)
#       Return the average best error of the experiment
#
#       Average best error is defined as the average of bandit.true_loss,
#       weighted by the probability that the corresponding bandit.loss is best.
#
#       For domains with loss measurement variance of 0, this function simply
#       returns the true_loss corresponding to the result with the lowest loss.
#
#   count_by_state_synced(self, arg, trials=None)
#       Return trial counts by looking at self._trials
#
#   count_by_state_unsynced(self, arg)
#       Return trial counts that count_by_state_synced would return if we
#       called refresh() first.
#
#   insert_trial_doc(self, doc)
#       insert trial after error checking
#
#       Does not refresh. Call self.refresh() for the trial to appear in
#       self.specs, self.results, etc.
#
#   insert_trial_docs(self, docs)
#       trials - something like is returned by self.new_trial_docs()
#
#   losses(self, bandit=None)
#
#   new_trial_docs(self, tids, specs, results, miscs)
#
#   new_trial_ids(self, n)
#
#   refresh(self)
#
#   source_trial_docs(self, tids, specs, results, miscs, sources)
#
#   statuses(self, bandit=None)
#
#   view(self, exp_key=None, refresh=True)
#
#   ----------------------------------------------------------------------
#   Readonly properties inherited from hyperopt.base.Trials:
#
#   argmin
#
#   best_trial
#       Trial with lowest non-NaN loss and status=STATUS_OK.
#       If no such trial exists, returns None.
#
#   idxs
#
#   idxs_vals
#
#   miscs
#
#   results
#
#   specs
#
#   tids
#
#   trials
#
#   vals
#
#   ----------------------------------------------------------------------
#   Data descriptors inherited from hyperopt.base.Trials:
#
#   __dict__
#       dictionary for instance variables (if defined)
#
#   __weakref__
#       list of weak references to the object (if defined)
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
